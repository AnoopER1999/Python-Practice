# %%
a = [11,22,33,44,55]

# %%
def twoSum(self,nums, target):
    mapping = {}
    for x, y in enumerate(nums):
        remainder = target - y
        if remainder in mapping:
            return [mapping[remainder], x]
        mapping[y] = x

# %%
two_sum(a,33)
# Out:
# [0, 1]

# %%
for x, y in enumerate(a):
    print(x,y)
# Out:
# 0 11
# 1 22
# 2 33
# 3 44
# 4 55

# %%
a
# Out:
# [11, 22, 33, 44, 55]

# %%
a[1]
# Out:
# 22

# %%
nums = [2,7,11,15]
target = 9

# %%
nums
# Out:
# [2, 7, 11, 15]

# %%
new_set = [ 9-i for i in nums]

# %%
new_set
# Out:
# [7, 2, -2, -6]

# %%
filtered = [ i for i in new_set if i in nums]

# %%
filtered
# Out:
# [7, 2]

# %%
index_id = sorted([nums.index(i) for i in filtered])

# %%
index_id
# Out:
# [0, 1]
